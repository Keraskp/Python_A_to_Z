# %% [markdown]
# # threading : A High level threading API in python

# %%
class Hello:
    def run(self):
        for i in range(5):
            print('Hello')
            
class Hi:
    def run(self):
        for i in range(5):
            print('Hi')
            
t1 = Hello()
t2 = Hi()

# %%
t1.run()
t2.run()

# %% [markdown]
# As expected, run() of t1 runs first and after completion, run() of t2 runs.
# Now, if we want to make them run parallely, we have to declare them sub-classes of class Thread.

# %%
from threading import *

# %%
class Hello(Thread):
    def run(self):
        for i in range(500):
            print('Hello')
            
class Hi(Thread):
    def run(self):
        for i in range(500):
            print('Hi')
            
#Now if we want to create threads, we have to use start() method, it will internally call run()
t1 = Hello()
t2 = Hi()

t1.start()
t2.start()
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# ...
